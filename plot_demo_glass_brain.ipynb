# %%
# %matplotlib inline

# %% [markdown]
# Glass brain plotting in nilearn
# ===============================
#
# See `plotting` for more plotting functionalities.

# %% [markdown]
# Retrieve data from Internet
# ---------------------------

# %%
from nilearn import datasets

localizer_dataset = datasets.fetch_localizer_button_task()
localizer_tmap_filename = localizer_dataset.tmaps[0]
# Out:
# Dataset created in /home/lou/nilearn_data/brainomics_localizer
#
# Downloading data from http://brainomics.cea.fr/localizer/brainomics_data_13.zip ...
# Downloaded 962832 of 962832 bytes (100.0%,    0.0s remaining) ...done. (2 seconds, 0 min)
# Extracting data from /home/lou/nilearn_data/brainomics_localizer/16a7c6bb5ff3cc356e29a0cca31ef022/brainomics_data_13.zip..... done.
# Downloading data from http://brainomics.cea.fr/localizer/dataset/cubicwebexport.csv ...
# Downloaded 1555 of 1555 bytes (100.0%,    0.0s remaining) ...done. (1 seconds, 0 min)
# Downloading data from http://brainomics.cea.fr/localizer/dataset/cubicwebexport2.csv ...
# Downloaded 64001 of 64001 bytes (100.0%,    0.0s remaining) ...done. (3 seconds, 0 min)

# %%
localizer_tmap_filename
# Out:
# '/home/lou/nilearn_data/brainomics_localizer/brainomics_data/S02/t_map_left_auditory_&_visual_click_vs_right_auditory&visual_click.nii.gz'

# %% [markdown]
# Glass brain plotting: whole brain sagittal cuts
# -----------------------------------------------

# %%
from nilearn import plotting

plotting.plot_glass_brain(localizer_tmap_filename, threshold=3)

# %% [markdown]
# Glass brain plotting: black backgrond
# -------------------------------------
# On a black background (option "black_bg"), and with only the x and
# the z view (option "display_mode").

# %%
plotting.plot_glass_brain(
    localizer_tmap_filename, title='plot_glass_brain',
    black_bg=True, display_mode='xz', threshold=3)

# %% [markdown]
# Glass brain plotting: Hemispheric sagittal cuts
# -----------------------------------------------

# %%
plotting.plot_glass_brain(localizer_tmap_filename,
                          title='plot_glass_brain with display_mode="lyrz"',
                          display_mode='lyrz', threshold=3)

plotting.show()
